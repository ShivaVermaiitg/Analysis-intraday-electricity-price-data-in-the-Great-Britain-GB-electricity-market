# %% [markdown]
# # Analysis intraday electricity price data in the Great Britain (GB) electricity market

# %%
import pandas as pd
# Out:
# <ipython-input-2-7dd3504c366f>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('gb_electricity_data.csv')

# %%
df.head()
# Out:
#    ELEXM_SETTLEMENT_PERIOD                  ELEXM_utc  \
# 0                       43  2008-11-05T21:00:00+00:00
# 1                       44  2008-11-05T21:30:00+00:00
# 2                       45  2008-11-05T22:00:00+00:00
# 3                       46  2008-11-05T22:30:00+00:00
# 4                       47  2008-11-05T23:00:00+00:00
#
#              ELEXM_localtime  ELEXM_ROWFLAG  NGEM_ROWFLAG  POWER_ESPENI_MW  \
# 0  2008-11-05T21:00:00+00:00              1             1            44020
# 1  2008-11-05T21:30:00+00:00              1             1            42169
# 2  2008-11-05T22:00:00+00:00              1             1            40228
# 3  2008-11-05T22:30:00+00:00              1             1            38349
# 4  2008-11-05T23:00:00+00:00              1             1            37640
#
#    POWER_ELEXM_CCGT_MW  POWER_ELEXM_OIL_MW  POWER_ELEXM_COAL_MW  \
# 0                16468                   0                19525
# ...

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["POWER_ESPENI_MW"])

# set x/y labels and plot title
plt.pyplot.xlabel("POWER_ESPENI_MW")
plt.pyplot.ylabel("Time")
plt.pyplot.title("POWER_ESPENI_MW Calculating Great Britain's half-hourly electrical demand")
# Out:
# Text(0.5, 1.0, "POWER_ESPENI_MW Calculating Great Britain's half-hourly electrical demand")

# %%
import piplite
await piplite.install('seaborn')

# %%
# Distribution plot for the predicted values and that of the actual values
import seaborn as sns
ax1 = sns.distplot(df['POWER_ESPENI_MW'], hist=False, color="r", label="Actual Value")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Proportion of POWER_ESPENI_MW')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()
# Out:
# <ipython-input-7-5d5115a5dbd5>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['POWER_ESPENI_MW'], hist=False, color="r", label="Actual Value")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 ax1 = sns.distplot(df['POWER_ESPENI_MW'], hist=False, color="r", label="Actual Value")
#       5 # Create a distribution plot for predicted values
# ----> 6 sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)
# ...
